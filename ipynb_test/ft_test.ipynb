# %%
import numpy as np
import sigtem as st
from matplotlib import pyplot as plt

# %%
s = st.ct_impulse(2)
a = s.get_ft()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
s = st.ct_unit_step()
a = s.get_ft()
a.show_all()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
s = st.ct_rect(1)
a = s.get_ft()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':

# %%
s = st.ct_rect_period(1,4)
a = s.get_fs()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':

# %%
s = st.dt_impulse(2,1)
a = s.get_ft()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
s = st.dt_unit_step()
a = s.get_ft()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
s = st.dt_exp(1,0,2,0)
a = s.get_ft()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
s = st.dt_exp(2,0,3,1)
a = s.get_ft()
a.show()
# Out:
# /Users/downing/Desktop/signal_t/sigtem/basic.py:61: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if t_array == 'self' and x_array == 'self':
# /Users/downing/opt/anaconda3/envs/data/lib/python3.8/site-packages/matplotlib/transforms.py:2837: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %%
s = st.dt_sample()
a = s.get_ft()
a.show()
